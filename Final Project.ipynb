# %% [markdown]
# <a href="https://colab.research.google.com/github/Dewak20/Data-Science-Project/blob/main/Final%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# for dataframe manipulations
import pandas as pd
# for Data Visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Load Data**

# %%
df = pd.read_csv('/content/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.describe(include='all')
# Out:
#                 age   sex          bmi  ...  smoker     region       charges
# count   1338.000000  1338  1338.000000  ...    1338       1338   1338.000000
# unique          NaN     2          NaN  ...       2          4           NaN
# top             NaN  male          NaN  ...      no  southeast           NaN
# freq            NaN   676          NaN  ...    1064        364           NaN
# mean      39.207025   NaN    30.663397  ...     NaN        NaN  13270.422265
# std       14.049960   NaN     6.098187  ...     NaN        NaN  12110.011237
# min       18.000000   NaN    15.960000  ...     NaN        NaN   1121.873900
# 25%       27.000000   NaN    26.296250  ...     NaN        NaN   4740.287150
# 50%       39.000000   NaN    30.400000  ...     NaN        NaN   9382.033000
# 75%       51.000000   NaN    34.693750  ...     NaN        NaN  16639.912515
# max       64.000000   NaN    53.130000  ...     NaN        NaN  63770.428010
#
# [11 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df['sex'].replace(['female', 'male'], [0,1], inplace=True)
df['smoker'].replace(['yes', 'no'], [0,1], inplace=True)
df['region'].replace(['southwest','southeast','northwest','northeast'], [0,1,2,3], inplace=True)
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       0       0  16884.92400
# 1      18    1  33.770         1       1       1   1725.55230
# 2      28    1  33.000         3       1       1   4449.46200
# 3      33    1  22.705         0       1       2  21984.47061
# 4      32    1  28.880         0       1       2   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       1       2  10600.54830
# 1334   18    0  31.920         0       1       3   2205.98080
# 1335   18    0  36.850         0       1       1   1629.83350
# 1336   21    0  25.800         0       1       0   2007.94500
# 1337   61    0  29.070         0       0       2  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['charges'] = df['charges'].astype(int)
df['bmi'] = df['bmi'].astype(int)
df
# Out:
#       age  sex  bmi  children  smoker  region  charges
# 0      19    0   27         0       0       0    16884
# 1      18    1   33         1       1       1     1725
# 2      28    1   33         3       1       1     4449
# 3      33    1   22         0       1       2    21984
# 4      32    1   28         0       1       2     3866
# ...   ...  ...  ...       ...     ...     ...      ...
# 1333   50    1   30         3       1       2    10600
# 1334   18    0   31         0       1       3     2205
# 1335   18    0   36         0       1       1     1629
# 1336   21    0   25         0       1       0     2007
# 1337   61    0   29         0       0       2    29141
#
# [1338 rows x 7 columns]

# %% [markdown]
# # **EDA**

# %%
#Plot the relationship of Charges by gender ratio

fig, ax = plt.subplots(figsize=(15,10))
sns.distplot(x=df.loc[df['sex']==1, 'charges'], label='male', ax=ax)
sns.distplot(x=df.loc[df['sex']==0, 'charges'], label='female', ax=ax)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.distplot(x=df.loc[df['smoker']==0, 'charges'], label='smoker', ax=ax)
sns.distplot(x=df.loc[df['smoker']==1, 'charges'], label='not smoker', ax=ax)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['age'],y=df['charges'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (15,10))
sns.scatterplot(x = "age", y = "charges", data = df, hue = "smoker")

plt.xlabel("Age")
plt.ylabel("Charges")
plt.title("Distribution of charges by age and smoker")
# Out:
# Text(0.5, 1.0, 'Distribution of charges by age and smoker')

# %%
plt.figure(figsize = (15,10))
sns.boxplot(x = "sex", y = "charges", data = df)
plt.xticks([0,1], ['female', 'male'])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# # **Model**

# %%
X =  df.drop(["region","charges"],axis=1)
X
# Out:
#       age  sex  bmi  children  smoker
# 0      19    0   27         0       0
# 1      18    1   33         1       1
# 2      28    1   33         3       1
# 3      33    1   22         0       1
# 4      32    1   28         0       1
# ...   ...  ...  ...       ...     ...
# 1333   50    1   30         3       1
# 1334   18    0   31         0       1
# 1335   18    0   36         0       1
# 1336   21    0   25         0       1
# 1337   61    0   29         0       0
#
# [1338 rows x 5 columns]

# %%
y = df['charges']
y
# Out:
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
#         ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
# Name: charges, Length: 1338, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2e0bfc0ea5b4> in <module>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=15)
#
# NameError: name 'X' is not defined

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (936, 5) (936,)
# (402, 5) (402,)

# %% [markdown]
# **Linear Regression**

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression

linear_regressor = LinearRegression()  


linear_regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# prints y-intercept
print(linear_regressor.intercept_)

# prints the coefficient
print(linear_regressor.coef_)
# Out:
# 11899.308900531874
# [   262.45552835    -27.18689224    312.54970482    545.05199615
#  -23725.51336496]

# %%
y_pred_lr = linear_regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_lr = r2_score(y_test.values, y_pred_lr)
print(r2_lr)
# Out:
# 0.7858320974802611

# %%
import numpy as np
plt.figure(figsize=(10,8))
plt.plot(np.arange(len(y_test)), y_test,label='Aktual')
plt.plot(np.arange(len(y_test)), y_pred_lr,label='Prediksi')
plt.title('Model Linear Regression')
plt.legend()
plt.show()

# %% [markdown]
# **Decision tree**

# %%
#Decision tree
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()

dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dt = dt.predict(X_test)

# %%
r2_dt = r2_score(y_test.values, y_pred_dt)
print(r2_dt)
# Out:
# 0.7423086560605431

# %%
plt.figure(figsize=(10,8))
plt.plot(np.arange(len(y_test)), y_test,label='Aktual')
plt.plot(np.arange(len(y_test)), y_pred_dt,label='Prediksi')
plt.title('Model Decision Tree')
plt.legend()
plt.show()

# %% [markdown]
# **Random Forest**

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=19)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=19)

# %%
y_pred_rf = rf.predict(X_test) 

r2_rf = r2_score(y_test.values, y_pred_rf)
print(r2_rf)
# Out:
# 0.8555214235949381

# %%
plt.figure(figsize=(10,8))
plt.plot(np.arange(len(y_test)), y_test,label='Aktual')
plt.plot(np.arange(len(y_test)), y_pred_rf,label='Prediksi')
plt.title('Model Random Forest')
plt.legend()
plt.show()

# %%
#Predict new data
data_new = X_train[:1]
rf.predict(data_new)
# Out:
# array([8333.26116667])

# %%
y_train[:1]
# Out:
# 525    11482
# Name: charges, dtype: int64

# %% [markdown]
# **Evaluasi Model**

# %%
print('Perbandingan Akurasi R2 Setiap Model')
print('==============================================')
print('Linear Regression       : {:.2f}'.format(r2_lr))
print('Decision Tree           : {:.2f}'.format(r2_dt))
print('Random Forest           : {:.2f}'.format(r2_rf))
# Out:
# Perbandingan Akurasi R2 Setiap Model
# ...
# Linear Regression       : 0.79
# Decision Tree           : 0.76
# Random Forest           : 0.86

# %%
plt.figure(figsize=(15,10))
plt.plot(np.arange(len(y_test)), y_test,label='Aktual')
plt.plot(np.arange(len(y_test)), y_pred_lr,label='LinearRegression')
plt.plot(np.arange(len(y_test)), y_pred_dt,label='DecisionTree')
plt.plot(np.arange(len(y_test)), y_pred_rf,label='RandomForest')
plt.title('Perbandingan Hasil Prediksi Setiap Model')
plt.legend()
plt.show()
